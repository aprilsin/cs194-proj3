# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import skimage as sk
import skimage.io as io
import matplotlib.pyplot as plt
from skimage.util import img_as_ubyte, img_as_float

# %%
import triangulation as tri
import utils, morph

# %%
from pathlib import Path
data = Path("input")
data.mkdir(parents=True, exist_ok=True)

# %%
DEFAULT_HEIGHT = 575
DEFAULT_WIDTH = 547
DEFAULT_SCALE = 0.35
PAD_MODE='edge'

img = utils.read_img('me.jpg')
points = [[ 865.68270077,  934.08218215],
       [1211.43666844,  948.0992349 ]]
left, right = points

eye_len = np.sqrt((right[1] - left[1]) ** 2 + (right[0] - left[0]) ** 2)

w = img.shape[1]
actual = eye_len / w
diff = actual - DEFAULT_SCALE
print(diff)
# if abs(diff) > 0.1:
#     return transform.rescale(img, scale=DEFAULT_SCALE / actual, preserve_range=True, multichannel=True, mode=PAD_MODE)
# return img
# Out:
# -0.17523334319727066

# %%
1/ (DEFAULT_SCALE / actual)
# Out:
# 0.4993333051506552

# %%
abs(diff) > 0.1
# Out:
# True

# %%
me = transform.rescale(img, scale= actual / DEFAULT_SCALE, preserve_range=True, multichannel=True, mode=PAD_MODE)

# %%
me.dtype
# Out:
# dtype('float64')

# %%
io.imshow(me)

# %%
import alignment
points = np.array([[ 865.68270077,  934.08218215],
   [1211.43666844,  948.0992349 ]])
left, right = points // 2
center = alignment.find_centers(left, right)
cx, cy = center

# %%
scale = 1
DEFAULT_HEIGHT = 575
DEFAULT_WIDTH = 547
col_start = cx - (DEFAULT_WIDTH * scale // 2 + PADDING)
col_end = cx + DEFAULT_WIDTH * scale // 2
row_start = cy - DEFAULT_HEIGHT * scale // 2
row_end = cy + DEFAULT_HEIGHT * scale // 2
row_start, row_end, col_start,col_end
# Out:
# (183, 757, 245, 791)

# %%
io.imshow(me[row_start:row_end, col_start:col_end, :])

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
scale
# Out:
# 2.0026703400012287

# %%
DEFAULT_WIDTH * scale // 2
# Out:
# 547

# %%
scale
# Out:
# 2

# %%
DEFAULT_WIDTH * scale
# Out:
# 1094

# %%
import utils
img = utils.read_img('me.jpg')
utils.get_points(img, 4)
# Out:
# Please select 4 points in image.
# array([[   0,    0],
#        [   0, 1980],
#        [2640,    0],
#        [2640, 1980]])
